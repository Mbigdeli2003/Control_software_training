# %% [markdown]
# <a href="https://colab.research.google.com/github/Mbigdeli2003/Control_software_training/blob/main/softwarecontrl_sesion2_TA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **به نام خدا**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split

# %%
X = pd.read_csv("/content/diabetes.csv")   ##

# %%
A=pd.DataFrame(X)

# %%
A.shape
# Out:
# (768, 9)

# %%
C=A['Glucose'].values

# %%
label=A['Outcome']

# %%
label.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
X_main=A.iloc[:,0:8]

# %%
X_main.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
X_1=A.iloc[:,0:4]

# %%
X_1.head()

# %%
X.describe()

# %%
L_interest=A.iloc[:,0:4]

# %%
L_interest.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness
# 0            6      148             72             35
# 1            1       85             66             29
# 2            8      183             64              0
# 3            1       89             66             23
# 4            0      137             40             35

# %%
X_1.head()

# %%
a= A['Glucose'].values

# %%
print(a)

# %%
plt.plot(a,'g')

# %%
X_feature=A.iloc[:,8]

# %%
X_feature.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
features=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
X = A.loc[:, features]
#y=X.iloc[:,7]
g=['Outcome']
y=A.loc[:,['Outcome']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, label, random_state=None, test_size=0.1)

# %%
X_train.head()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.preprocessing import MaxAbsScaler
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(X_train)
normalized_df = pd.DataFrame(normalized_data)
normalized_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.294118  0.718593  0.639344  0.000000  0.000000  0.670641  0.047822
# 1  0.000000  0.869347  0.639344  0.323232  0.313239  0.692996  0.461571
# 2  0.411765  0.407035  0.639344  0.404040  0.056738  0.695976  0.078138
# 3  0.294118  0.949749  0.524590  0.333333  0.384161  0.464978  0.215628
# 4  0.588235  0.648241  0.622951  0.282828  0.144208  0.535022  0.086251
#
#           7
# 0  0.433333
# 1  0.616667
# 2  0.350000
# 3  0.133333
# 4  0.300000
